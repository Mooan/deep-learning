# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random, math
def subsampling(threshold):
    arr = []
    word_counts = Counter(int_words)
    total_count = len(int_words)
    #for word, count in word_counts:
    #    freq = count/word_counts
    #    p = 1.0 - math.sqrt(threshold/freq)
    #    if p <= random.random():
    #        arr.append(i)
    freqs  = {word: count/total_count for word, count in word_counts.items()}
    p_drop = {word: 1.0 - np.sqrt(threshold/freqs[word]) for word in word_counts}
    return [word for word in int_words if p_drop[word] < random.random() ]

train_words = subsampling(1e-5)

# %%
print( len(train_words), len(int_words) )
# Out:
# 4628714 16680599

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = math.ceil(random.random() * window_size)
    start = idx - r if ( idx - r ) > 0 else 0
    stop  = idx + r
    target_words = set( words[start:idx] + words[idx+1:stop+1] )
    return list(target_words)
#get_target(int_words, 9)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None])
    labels = tf.placeholder(tf.int32, shape=[None, None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 300 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1) ) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss (softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.7579 0.0304 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.7286 0.0218 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.6296 0.0218 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.7100 0.0218 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.6097 0.0217 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.6510 0.0218 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.6564 0.0218 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.6533 0.0217 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5796 0.0217 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.5243 0.0217 sec/batch
# Nearest to these: tailplane, indra, forage, erectus, exegetes, amerikkka, ingersoll, distort,
# Nearest to see: ong, pragmatically, plaudits, symptomatic, impious, ingest, lingerie, reheat,
# Nearest to for: shema, marta, gym, logan, analogy, elphinstone, pix, feathers,
# Nearest to an: domestication, mainstream, landlord, seamanship, isabel, pollinated, herons, amhr,
# Nearest to one: glassy, dorchester, intertwined, monti, cutbacks, pagemaker, prosthetics, kirov,
# Nearest to by: esplanade, syntax, cognate, erstwhile, spaulding, apps, carly, montague,
# Nearest to however: augustus, adaptive, keweenaw, fridays, lifesaving, composting, tetralogy, wrapped,
# Nearest to so: banishment, arachne, land, lyme, wagons, quell, trintignant, jena,
# Nearest to hit: meccan, contemplative, centimeter, predetermined, whoso, comenius, mel, burlington,
# Nearest to shown: gives, resonances, whaler, broughton, infancy, branden, cheque, shankara,
# Nearest to writers: zimri, compulsories, relieve, excommunicates, baserunner, insights, lynda, depths,
# Nearest to report: cacao, whims, remit, araki, anemones, decry, complete, contraband,
# Nearest to mathematics: excalibur, trel, swindon, edicts, braithwaite, assent, yana, uematsu,
# Nearest to consists: branson, claim, derisively, load, eleonore, amiable, cinq, gr,
# Nearest to frac: dagome, brower, gemara, waitakere, guralnick, pw, bnetd, phyllis,
# Nearest to lived: sing, rain, maleev, squaresoft, keiretsu, photographs, spread, sittings,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5312 0.0231 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4300 0.0219 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.4207 0.0219 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.3034 0.0218 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2684 0.0217 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2235 0.0218 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1577 0.0218 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1348 0.0218 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0376 0.0218 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0423 0.0218 sec/batch
# Nearest to these: indra, forage, erectus, amerikkka, tailplane, tide, distort, identifying,
# Nearest to see: ong, supplies, plaudits, discontinued, pragmatically, symptomatic, dance, synonymous,
# Nearest to for: desire, within, analogy, shema, vision, databank, elphinstone, money,
# Nearest to an: mainstream, realizing, domestication, better, essential, stay, elapsed, landlord,
# Nearest to one: glassy, dorchester, miles, intertwined, monti, kilometers, chuck, coronation,
# Nearest to by: syntax, cut, apps, applying, consciously, funk, march, classed,
# Nearest to however: adaptive, augustus, fridays, julio, end, composting, lifesaving, keweenaw,
# Nearest to so: land, conventions, able, plural, banishment, wagons, preset, nadi,
# Nearest to hit: meccan, contemplative, centimeter, predetermined, house, location, newtonian, mel,
# Nearest to shown: gives, resonances, broughton, infancy, whaler, sometimes, branden, achieve,
# Nearest to writers: relieve, zimri, compulsories, conducted, insights, depths, thanks, tribulations,
# Nearest to report: cacao, complete, score, whims, remit, vigil, assign, omnia,
# Nearest to mathematics: swindon, excalibur, assent, braithwaite, machines, attacked, yana, symphonie,
# Nearest to consists: claim, branson, load, orange, postures, culpability, derisively, conspicuous,
# Nearest to frac: dagome, guralnick, brower, pw, gemara, relax, bnetd, later,
# Nearest to lived: rain, sing, spread, photographs, maleev, squaresoft, restoration, encouraging,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 5.0019 0.0229 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9841 0.0218 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9394 0.0220 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9254 0.0220 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8654 0.0217 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8796 0.0218 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8408 0.0217 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8494 0.0217 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8489 0.0218 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8249 0.0218 sec/batch
# Nearest to these: indra, forage, tailplane, amerikkka, erectus, compiles, tide, distort,
# Nearest to see: ong, plaudits, pragmatically, dance, symptomatic, protector, delegation, transcended,
# Nearest to for: desire, analogy, shema, within, vision, gym, elphinstone, sleep,
# Nearest to an: domestication, elapsed, realizing, mainstream, better, pollinated, stay, landlord,
# Nearest to one: glassy, dorchester, giuseppe, miles, coronation, chuck, intertwined, kilometers,
# Nearest to by: funk, syntax, applying, apps, consciously, cut, wealth, cognate,
# Nearest to however: augustus, adaptive, fridays, composting, wrapped, keweenaw, lifesaving, dune,
# Nearest to so: banishment, jena, land, participant, quell, contraception, conventions, preset,
# Nearest to hit: predetermined, meccan, contemplative, centimeter, mel, newtonian, house, burlington,
# Nearest to shown: gives, whaler, resonances, infancy, broughton, cheque, automatic, branden,
# Nearest to writers: zimri, relieve, depths, thanks, compulsories, conducted, huber, baserunner,
# Nearest to report: cacao, whims, score, remit, complete, vigil, trespassing, contraband,
# Nearest to mathematics: swindon, assent, excalibur, machines, braithwaite, complex, quit, yana,
# Nearest to consists: branson, claim, load, postures, imitation, orange, derisively, eleonore,
# Nearest to frac: dagome, guralnick, brower, relax, loudspeakers, pw, torvalds, shorten,
# Nearest to lived: sing, rain, photographs, spread, maleev, indicted, constitutes, annexing,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8279 0.0230 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.8261 0.0219 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7619 0.0220 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7842 0.0216 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.8131 0.0219 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7748 0.0219 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7379 0.0220 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7643 0.0222 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7492 0.0221 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6781 0.0218 sec/batch
# Nearest to these: indra, tailplane, forage, amerikkka, identifying, exegetes, compiles, sticker,
# Nearest to see: pragmatically, ong, plaudits, transcended, jericho, lingerie, impious, symptomatic,
# Nearest to for: desire, shema, gym, analogy, waning, sleep, elphinstone, vision,
# Nearest to an: domestication, elapsed, gallup, seamanship, landlord, mainstream, realizing, pollinated,
# Nearest to one: giuseppe, dorchester, chuck, two, miles, glassy, monti, nasdaq,
# Nearest to by: funk, erstwhile, apps, alexandra, march, classed, moi, donation,
# Nearest to however: augustus, wrapped, composting, adaptive, fridays, keweenaw, arching, lifesaving,
# Nearest to so: jena, banishment, contraception, quell, land, fairtrade, unsuspecting, nadi,
# Nearest to hit: meccan, contemplative, predetermined, centimeter, mel, burlington, whoso, location,
# Nearest to shown: gives, cheque, whaler, resonances, broughton, infancy, branden, automatic,
# Nearest to writers: zimri, depths, relieve, rohypnol, compulsories, thanks, baserunner, empress,
# Nearest to report: whims, cacao, remit, contraband, anemones, kaunda, vigil, decry,
# Nearest to mathematics: braithwaite, excalibur, swindon, redistricting, assent, complex, slander, machines,
# Nearest to consists: branson, claim, load, derisively, imitation, digestive, amiable, rouen,
# Nearest to frac: dagome, brower, relax, loudspeakers, torvalds, guralnick, shorten, pw,
# Nearest to lived: sing, rain, indicted, annexing, photographs, constitutes, maleev, installer,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7425 0.0228 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6834 0.0219 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6570 0.0220 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6617 0.0218 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6678 0.0218 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6654 0.0220 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5991 0.0159 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5620 0.0218 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4848 0.0219 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5028 0.0218 sec/batch
# Nearest to these: tailplane, indra, forage, compiles, amerikkka, identifying, sticker, jacobites,
# Nearest to see: ong, plaudits, pragmatically, lingerie, transcended, jericho, symptomatic, discontinued,
# Nearest to for: gym, shema, euphemistically, waning, desire, postscript, analogy, activating,
# Nearest to an: elapsed, domestication, landlord, gallup, seamanship, realizing, pollinated, profiling,
# Nearest to one: giuseppe, two, dorchester, retires, eight, chuck, monti, coronation,
# Nearest to by: erstwhile, funk, apps, pedophile, donation, esplanade, applying, moi,
# Nearest to however: wrapped, composting, augustus, keweenaw, fridays, changer, adaptive, rif,
# Nearest to so: jena, contraception, quell, fairtrade, participant, unsuspecting, banishment, arachne,
# Nearest to hit: meccan, contemplative, predetermined, centimeter, kirchner, burlington, whoso, mel,
# Nearest to shown: gives, cheque, whaler, resonances, infancy, longed, broughton, branden,
# Nearest to writers: zimri, depths, rohypnol, baserunner, compulsories, thanks, upanishad, tragedy,
# Nearest to report: cacao, whims, contraband, anemones, remit, proclaimed, complete, vigil,
# Nearest to mathematics: excalibur, braithwaite, complex, redistricting, swindon, machines, bbses, elt,
# Nearest to consists: branson, load, claim, derisively, pago, digestive, amiable, imitation,
# Nearest to frac: dagome, brower, relax, satisfies, loudspeakers, torvalds, guralnick, equation,
# Nearest to lived: sing, rain, annexing, indicted, maleev, photographs, alexander, installer,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4756 0.0228 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5035 0.0217 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4397 0.0219 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5133 0.0220 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4954 0.0218 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4751 0.0220 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4279 0.0218 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3602 0.0217 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4024 0.0217 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3836 0.0218 sec/batch
# Nearest to these: tailplane, forage, compiles, identifying, indra, sticker, amerikkka, referent,
# Nearest to see: plaudits, lingerie, ong, transcended, pragmatically, discontinued, rhetoric, maimonides,
# Nearest to for: euphemistically, gym, shema, desire, postscript, waning, reactor, inoffensive,
# Nearest to an: elapsed, domestication, realizing, profiling, landlord, pollinated, seamanship, mainstream,
# Nearest to one: dorchester, retires, two, giuseppe, kilometers, chuck, monti, ivor,
# Nearest to by: pedophile, erstwhile, apps, donation, esplanade, screenshot, consciously, funk,
# Nearest to however: composting, keweenaw, augustus, wrapped, adaptive, fridays, thereby, changer,
# Nearest to so: quell, jena, unsuspecting, banishment, fairtrade, contraception, arachne, nadi,
# Nearest to hit: meccan, contemplative, sox, pitch, mel, predetermined, whoso, centimeter,
# Nearest to shown: gives, cheque, whaler, resonances, switch, broughton, sometimes, automatic,
# Nearest to writers: zimri, depths, compulsories, baserunner, upanishad, rohypnol, thanks, tragedy,
# Nearest to report: whims, cacao, contraband, priss, anemones, remit, complete, araki,
# Nearest to mathematics: excalibur, braithwaite, complex, redistricting, elt, bijection, machines, axioms,
# Nearest to consists: branson, digestive, derisively, load, pago, amiable, hashshashin, claim,
# Nearest to frac: dagome, function, equation, satisfies, sqrt, tangent, relax, loudspeakers,
# Nearest to lived: sing, rain, indicted, maleev, registrar, alexander, paris, portage,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4319 0.0228 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4131 0.0218 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4031 0.0219 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3641 0.0219 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4175 0.0218 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4445 0.0218 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3393 0.0218 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3431 0.0218 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3992 0.0217 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3834 0.0217 sec/batch
# Nearest to these: tailplane, forage, compiles, identifying, sticker, exegetes, indra, amerikkka,
# Nearest to see: plaudits, ong, lingerie, pragmatically, discontinued, transcended, maimonides, jericho,
# Nearest to for: euphemistically, desire, gym, postscript, waning, shema, fungal, educating,
# Nearest to an: elapsed, realizing, profiling, seamanship, domestication, pollinated, queue, mainstream,
# Nearest to one: two, dorchester, retires, ivor, chuck, eight, kilometers, giuseppe,
# Nearest to by: squaring, pedophile, screenshot, applying, erstwhile, apps, funk, ena,
# Nearest to however: composting, keweenaw, augustus, thereby, adaptive, fridays, fluency, changer,
# Nearest to so: functionary, unsuspecting, fairtrade, banishment, contraception, quell, jena, able,
# Nearest to hit: meccan, contemplative, sox, mel, pitch, phillies, kirchner, whoso,
# Nearest to shown: gives, resonances, cheque, whaler, broughton, branden, automatic, longed,
# Nearest to writers: zimri, upanishad, compulsories, baserunner, depths, thanks, rohypnol, kinnear,
# Nearest to report: whims, cacao, contraband, independents, priss, anemones, araki, taverns,
# Nearest to mathematics: braithwaite, complex, excalibur, empirical, machines, bijection, slander, axioms,
# Nearest to consists: branson, digestive, amiable, pago, load, claim, derisively, hashshashin,
# Nearest to frac: sqrt, dagome, tangent, velocity, satisfies, function, definable, equation,
# Nearest to lived: sing, him, paris, indicted, rain, registrar, alexander, annexing,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3698 0.0228 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3839 0.0218 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3517 0.0218 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3705 0.0218 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3886 0.0217 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3573 0.0218 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3836 0.0218 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3667 0.0218 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.2874 0.0217 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3026 0.0217 sec/batch
# Nearest to these: tailplane, forage, compiles, identifying, indra, jacobites, laborers, sticker,
# Nearest to see: plaudits, ong, lingerie, pragmatically, discontinued, transcended, jericho, maimonides,
# Nearest to for: euphemistically, postscript, desire, waning, fungal, educating, gym, shema,
# Nearest to an: elapsed, profiling, domestication, stampede, seamanship, pollinated, queue, realizing,
# Nearest to one: two, eight, dorchester, ivor, kilometers, retires, zero, purchased,
# Nearest to by: pedophile, apps, march, ena, squaring, erstwhile, screenshot, guaranteed,
# Nearest to however: keweenaw, composting, augustus, thereby, adaptive, fluency, changer, spreading,
# Nearest to so: unsuspecting, functionary, quell, fairtrade, contraception, wagons, jena, arachne,
# Nearest to hit: meccan, phillies, sox, contemplative, mel, pitch, centimeter, whoso,
# Nearest to shown: gives, resonances, cheque, whaler, branden, hammersmith, automatic, longed,
# Nearest to writers: zimri, upanishad, compulsories, baserunner, depths, thanks, kinnear, mention,
# Nearest to report: whims, cacao, contraband, independents, priss, godless, atat, complete,
# Nearest to mathematics: braithwaite, empirical, excalibur, complex, slander, bijection, seti, redistricting,
# Nearest to consists: branson, digestive, pago, amiable, radiodiffusion, derisively, load, imitation,
# Nearest to frac: sqrt, tangent, dagome, satisfies, function, velocity, equation, definable,
# Nearest to lived: him, sing, registrar, alexander, rain, paris, spread, israelites,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3487 0.0228 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2876 0.0218 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3586 0.0219 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3786 0.0217 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3856 0.0218 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2965 0.0218 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3080 0.0217 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3295 0.0217 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2154 0.0219 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2952 0.0217 sec/batch
# Nearest to these: tailplane, forage, compiles, identifying, amerikkka, jacobites, laborers, sticker,
# Nearest to see: plaudits, ong, lingerie, pragmatically, maimonides, jericho, discontinued, insular,
# Nearest to for: euphemistically, postscript, denoted, fungal, desire, shema, waning, gym,
# Nearest to an: elapsed, domestication, profiling, stay, stampede, pollinated, seamanship, landlord,
# Nearest to one: two, eight, dorchester, retires, ivor, nine, chuck, zero,
# Nearest to by: pedophile, march, in, apps, affluence, ena, diemen, rogan,
# Nearest to however: composting, thereby, keweenaw, augustus, naturals, changer, spreading, fridays,
# Nearest to so: unsuspecting, quell, wagons, jena, functionary, fairtrade, twelver, reap,
# Nearest to hit: meccan, phillies, sox, mel, contemplative, pitch, centimeter, teammate,
# Nearest to shown: gives, resonances, cheque, whaler, switch, branden, longed, automatic,
# Nearest to writers: zimri, upanishad, compulsories, baserunner, thanks, excommunicates, rohypnol, depths,
# Nearest to report: whims, cacao, reporting, priss, godless, independents, contraband, complete,
# Nearest to mathematics: empirical, braithwaite, complex, excalibur, axioms, redistricting, elt, bijection,
# Nearest to consists: branson, pago, digestive, radiodiffusion, amiable, derisively, hashshashin, linden,
# Nearest to frac: sqrt, tangent, dagome, satisfies, equation, velocity, interval, definable,
# Nearest to lived: him, sing, paris, rain, registrar, israelites, alexander, spread,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3015 0.0228 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3009 0.0218 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3124 0.0097 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2698 0.0217 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1846 0.0218 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1888 0.0218 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1846 0.0217 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1867 0.0217 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1784 0.0217 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1331 0.0217 sec/batch
# Nearest to these: tailplane, forage, compiles, laborers, jacobites, identifying, gneisses, firewalls,
# Nearest to see: plaudits, ong, lingerie, pragmatically, maimonides, jericho, transcended, insular,
# Nearest to for: euphemistically, postscript, shema, waning, fungal, gym, denoted, avtovaz,
# Nearest to an: elapsed, domestication, sqq, stay, pollinated, profiling, stampede, landlord,
# Nearest to one: two, eight, dorchester, ivor, retires, kilometers, patois, zero,
# Nearest to by: pedophile, esplanade, in, erstwhile, visby, virginian, apps, affluence,
# Nearest to however: keweenaw, composting, augustus, thereby, spreading, adaptive, wahid, moralia,
# Nearest to so: unsuspecting, quell, functionary, arachne, vehicle, jena, banishment, estranged,
# Nearest to hit: pitch, sox, phillies, mel, teammate, meccan, dogwood, waist,
# Nearest to shown: gives, resonances, cheque, longed, whaler, branden, testosterone, truthful,
# Nearest to writers: zimri, upanishad, compulsories, excommunicates, baserunner, novelists, tragedy, depths,
# Nearest to report: whims, cacao, reporting, priss, contraband, independents, taverns, atat,
# Nearest to mathematics: empirical, braithwaite, axioms, complex, redistricting, elt, excalibur, untie,
# Nearest to consists: branson, radiodiffusion, pago, digestive, linden, derisively, amiable, hashshashin,
# Nearest to frac: sqrt, tangent, dagome, satisfies, velocity, equation, definable, brower,
# Nearest to lived: him, registrar, paris, sing, rain, israelites, spread, alexander,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2016 0.0228 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1838 0.0217 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2016 0.0218 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1057 0.0218 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1174 0.0218 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1363 0.0218 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1093 0.0217 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1430 0.0220 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1676 0.0222 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1369 0.0219 sec/batch
# Nearest to these: tailplane, forage, compiles, identifying, gneisses, tasks, laborers, shows,
# Nearest to see: plaudits, ong, lingerie, maimonides, pragmatically, transcended, discontinued, jericho,
# Nearest to for: euphemistically, postscript, fungal, shema, the, denoted, waning, avtovaz,
# Nearest to an: elapsed, sqq, domestication, stay, stampede, realizing, gallup, profiling,
# Nearest to one: two, eight, dorchester, retires, ivor, zero, kilometers, patois,
# Nearest to by: in, esplanade, pedophile, visby, apps, miner, ena, screenshot,
# Nearest to however: composting, keweenaw, thereby, adaptive, augustus, zoster, wahid, naturals,
# Nearest to so: quell, unsuspecting, banishment, estranged, functionary, reap, able, nadi,
# Nearest to hit: pitch, phillies, sox, mel, teammate, dogwood, waist, contemplative,
# Nearest to shown: gives, resonances, cheque, longed, testosterone, whaler, branden, placebo,
# Nearest to writers: zimri, compulsories, upanishad, novelists, excommunicates, depths, baserunner, tragedy,
# Nearest to report: whims, reporting, priss, contraband, compliance, taverns, independents, preprocessing,
# Nearest to mathematics: empirical, braithwaite, complex, elt, redistricting, axioms, excalibur, quadratic,
# Nearest to consists: branson, radiodiffusion, pago, digestive, linden, load, derisively, amiable,
# Nearest to frac: sqrt, tangent, velocity, dagome, satisfies, equation, definable, interval,
# Nearest to lived: him, rain, registrar, sing, paris, israelites, spread, indicted,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1820 0.0229 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1688 0.0220 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1301 0.0221 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1274 0.0218 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1321 0.0218 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1905 0.0220 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1833 0.0221 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1140 0.0222 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1117 0.0222 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1665 0.0220 sec/batch
# Nearest to these: tailplane, compiles, forage, identifying, laborers, gneisses, themselves, amerikkka,
# Nearest to see: plaudits, lingerie, ong, pragmatically, maimonides, transcended, jericho, insular,
# Nearest to for: euphemistically, the, postscript, cohen, vernal, fungal, denoted, shema,
# Nearest to an: elapsed, sqq, domestication, stampede, gallup, stay, oo, seamanship,
# Nearest to one: two, eight, zero, nine, ivor, dorchester, retires, patois,
# Nearest to by: in, squaring, footnotes, march, sweeney, pedophile, guaranteed, laureates,
# Nearest to however: composting, thereby, keweenaw, augustus, fluency, prices, adaptive, zoster,
# Nearest to so: unsuspecting, quell, functionary, estranged, banishment, reap, superscript, whenever,
# Nearest to hit: pitch, mel, phillies, meccan, dogwood, sox, teammate, portsea,
# Nearest to shown: gives, resonances, longed, cheque, placebo, branden, whaler, testosterone,
# Nearest to writers: novelists, compulsories, zimri, upanishad, excommunicates, depths, ambiguously, baserunner,
# Nearest to report: whims, reporting, compliance, priss, cacao, taverns, independents, contraband,
# Nearest to mathematics: empirical, braithwaite, complex, elt, quadratic, redistricting, axioms, cyber,
# Nearest to consists: branson, pago, radiodiffusion, linden, imitation, hashshashin, derisively, digestive,
# Nearest to frac: sqrt, velocity, tangent, equation, dagome, satisfies, definable, loudspeakers,
# Nearest to lived: him, paris, rain, israelites, spread, sing, registrar, fulgencio,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1761 0.0229 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1452 0.0220 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1526 0.0219 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1558 0.0219 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1327 0.0219 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0881 0.0217 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1466 0.0217 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1041 0.0219 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1658 0.0220 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2085 0.0219 sec/batch
# Nearest to these: tailplane, forage, compiles, laborers, identifying, gneisses, firewalls, have,
# Nearest to see: plaudits, ong, lingerie, pragmatically, transcended, jericho, maimonides, insular,
# Nearest to for: euphemistically, the, cohen, bertha, awarded, dozenal, raoul, shema,
# Nearest to an: carter, stay, stampede, sqq, gallup, mobster, pompeii, elapsed,
# Nearest to one: two, eight, zero, nine, ivor, dorchester, retires, four,
# Nearest to by: in, march, footnotes, sweeney, guaranteed, squaring, ostankino, pedophile,
# Nearest to however: composting, augustus, thereby, keweenaw, adaptive, naturals, fluency, coprime,
# Nearest to so: unsuspecting, quell, estranged, functionary, reap, banishment, jena, able,
# Nearest to hit: phillies, mel, pitch, teammate, dogwood, centimeter, contemplative, sox,
# Nearest to shown: gives, resonances, cheque, longed, branden, placebo, truthful, outfit,
# Nearest to writers: novelists, compulsories, upanishad, zimri, excommunicates, deaths, depths, tragedy,
# Nearest to report: whims, reporting, compliance, priss, taverns, cacao, ngos, zeitung,
# Nearest to mathematics: empirical, braithwaite, elt, redistricting, complex, excalibur, ptolemaic, cyber,
# Nearest to consists: radiodiffusion, branson, pago, linden, derisively, geography, digestive, hashshashin,
# Nearest to frac: sqrt, velocity, tangent, dagome, equation, satisfies, definable, loudspeakers,
# Nearest to lived: him, paris, spread, rain, israelites, registrar, lipsius, infancy,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1956 0.0227 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1092 0.0217 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1096 0.0217 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1335 0.0217 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.9856 0.0218 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1277 0.0218 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1486 0.0217 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0981 0.0217 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1552 0.0037 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1102 0.0218 sec/batch
# Nearest to these: tailplane, forage, compiles, have, identifying, gneisses, tasks, firewalls,
# Nearest to see: pragmatically, plaudits, ong, lingerie, jericho, transcended, maimonides, insular,
# Nearest to for: the, euphemistically, fungal, dozenal, postscript, awarded, shema, its,
# Nearest to an: stay, pompeii, elapsed, seamanship, carter, zee, independant, gpa,
# Nearest to one: two, eight, zero, nine, five, dorchester, retires, ivor,
# Nearest to by: in, march, sweeney, affluence, ostankino, squaring, rogan, laureates,
# Nearest to however: composting, keweenaw, augustus, naturals, thereby, zoster, hysteria, spreading,
# Nearest to so: unsuspecting, quell, estranged, reap, functionary, jena, superscript, vehicle,
# Nearest to hit: pitch, mel, phillies, teammate, centimeter, waist, contemplative, sox,
# Nearest to shown: resonances, gives, longed, cheque, placebo, truthful, kidnapped, armies,
# Nearest to writers: novelists, compulsories, upanishad, zimri, deaths, tragedy, excommunicates, depths,
# Nearest to report: whims, reporting, taverns, compliance, priss, ngos, complete, contraband,
# Nearest to mathematics: empirical, braithwaite, elt, cyber, redistricting, complex, trel, quadratic,
# Nearest to consists: branson, radiodiffusion, pago, linden, consisting, runs, digestive, imitation,
# Nearest to frac: velocity, sqrt, tangent, dagome, gemara, equation, waitakere, marginal,
# Nearest to lived: him, paris, spread, registrar, rain, lipsius, fulgencio, portage,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0834 0.0228 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0377 0.0219 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0532 0.0218 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0096 0.0218 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 3.9887 0.0218 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9922 0.0218 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0567 0.0218 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0713 0.0218 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0739 0.0218 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9980 0.0217 sec/batch
# Nearest to these: tailplane, forage, compiles, have, identifying, gneisses, for, firewalls,
# Nearest to see: pragmatically, plaudits, ong, transcended, lingerie, jericho, maimonides, insular,
# Nearest to for: the, euphemistically, shema, fungal, its, postscript, avtovaz, these,
# Nearest to an: stay, pompeii, domestication, propylaea, transnational, filesystems, fm, sqq,
# Nearest to one: two, eight, nine, zero, five, retires, four, dorchester,
# Nearest to by: in, march, squaring, affluence, sweeney, advancements, laureates, produce,
# Nearest to however: composting, keweenaw, to, zoster, augustus, hysteria, that, spreading,
# Nearest to so: quell, unsuspecting, estranged, banishment, functionary, memex, arachne, reap,
# Nearest to hit: pitch, mel, phillies, dogwood, teammate, waist, contemplative, sox,
# Nearest to shown: resonances, longed, placebo, gives, armies, kidnapped, cheque, testosterone,
# Nearest to writers: novelists, upanishad, compulsories, deaths, excommunicates, tragedy, poets, zimri,
# Nearest to report: whims, reporting, compliance, taverns, ngos, priss, zeitung, contraband,
# Nearest to mathematics: empirical, braithwaite, elt, cyber, redistricting, trel, complex, quadratic,
# Nearest to consists: radiodiffusion, branson, pago, linden, consisting, geography, runs, load,
# Nearest to frac: velocity, sqrt, tangent, dagome, equation, gemara, quantity, antiderivatives,
# Nearest to lived: him, registrar, spread, paris, lipsius, infancy, portage, rain,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9814 0.0228 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0302 0.0217 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9868 0.0216 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0426 0.0217 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0316 0.0217 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0058 0.0217 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0463 0.0218 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0725 0.0217 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0074 0.0217 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0239 0.0217 sec/batch
# Nearest to these: compiles, tailplane, forage, have, identifying, gneisses, tasks, for,
# Nearest to see: pragmatically, plaudits, ong, jericho, lingerie, transcended, maimonides, insular,
# Nearest to for: the, euphemistically, avtovaz, postscript, its, shema, dozenal, alphanumeric,
# Nearest to an: a, oo, stay, proton, filesystems, transnational, gpa, domestication,
# Nearest to one: two, eight, nine, zero, five, four, seven, six,
# Nearest to by: in, squaring, march, laureates, footnotes, produce, affluence, identified,
# Nearest to however: composting, keweenaw, zoster, to, adaptive, mass, naturals, thereby,
# Nearest to so: unsuspecting, quell, memex, jena, reap, functionary, nadi, superscript,
# Nearest to hit: pitch, mel, phillies, dogwood, centimeter, contemplative, waist, teammate,
# Nearest to shown: resonances, placebo, gives, longed, testosterone, phosphate, armies, quench,
# Nearest to writers: novelists, compulsories, deaths, upanishad, poets, dramatists, excommunicates, fellows,
# Nearest to report: whims, reporting, compliance, taverns, ngos, priss, zeitung, reissue,
# Nearest to mathematics: empirical, complex, braithwaite, elt, variational, redistricting, cyber, ptolemaic,
# Nearest to consists: consisting, radiodiffusion, branson, pago, linden, load, does, assembly,
# Nearest to frac: velocity, sqrt, tangent, quantity, dagome, gemara, equation, marginal,
# Nearest to lived: him, spread, paris, rain, infancy, lipsius, registrar, warrens,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0284 0.0227 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0765 0.0217 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0149 0.0218 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0239 0.0217 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0167 0.0217 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0012 0.0218 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0450 0.0216 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0192 0.0218 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0580 0.0218 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0340 0.0217 sec/batch
# Nearest to these: compiles, tailplane, forage, have, laborers, teleological, firewalls, gneisses,
# Nearest to see: plaudits, pragmatically, jericho, ong, lingerie, maimonides, transcended, insular,
# Nearest to for: the, magyars, euphemistically, shema, awarded, all, avtovaz, its,
# Nearest to an: stay, transnational, pompeii, domestication, homophobia, sqq, mobster, zee,
# Nearest to one: two, eight, nine, zero, five, four, seven, six,
# Nearest to by: in, march, footnotes, laureates, squaring, advancements, guaranteed, heath,
# Nearest to however: composting, to, zoster, augustus, keweenaw, spreading, mass, coprime,
# Nearest to so: unsuspecting, quell, functionary, estranged, memex, banishment, jena, able,
# Nearest to hit: pitch, mel, phillies, centimeter, contemplative, teammate, dogwood, sox,
# Nearest to shown: resonances, longed, placebo, gives, kidnapped, outfit, armies, phosphate,
# Nearest to writers: novelists, compulsories, poets, deaths, burials, upanishad, excommunicates, cliche,
# Nearest to report: whims, compliance, reporting, taverns, zeitung, ngos, priss, jazeera,
# Nearest to mathematics: empirical, complex, ptolemaic, elt, braithwaite, redistricting, variational, cyber,
# Nearest to consists: consisting, radiodiffusion, linden, pago, branson, imitation, congruent, frictional,
# Nearest to frac: velocity, sqrt, quantity, tangent, gemara, dagome, waitakere, equation,
# Nearest to lived: him, paris, spread, infancy, warrens, lipsius, annexing, age,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0047 0.0227 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0011 0.0217 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0123 0.0217 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0372 0.0220 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0579 0.0219 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0976 0.0219 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0883 0.0219 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0375 0.0217 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9905 0.0218 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0166 0.0218 sec/batch
# Nearest to these: compiles, forage, tailplane, have, gneisses, firewalls, shows, identifying,
# Nearest to see: pragmatically, plaudits, ong, jericho, lingerie, insular, maimonides, transcended,
# Nearest to for: the, euphemistically, alphanumeric, avtovaz, nonempty, shema, awarded, denoted,
# Nearest to an: nonterminal, a, stay, pompeii, gallup, transnational, propylaea, gpa,
# Nearest to one: two, eight, nine, zero, five, four, retires, seven,
# Nearest to by: in, march, footnotes, squaring, affluence, defaulting, produce, laureates,
# Nearest to however: to, composting, keweenaw, zoster, coprime, that, mass, thereby,
# Nearest to so: unsuspecting, quell, estranged, memex, superscript, reap, able, functionary,
# Nearest to hit: mel, phillies, centimeter, pitch, teammate, contemplative, portsea, dogwood,
# Nearest to shown: resonances, placebo, longed, phosphate, gives, testosterone, kidnapped, outfit,
# Nearest to writers: novelists, poets, compulsories, deaths, fellows, alumni, burials, dramatists,
# Nearest to report: reporting, whims, compliance, ngos, taverns, jazeera, hadron, zeitung,
# Nearest to mathematics: empirical, ptolemaic, braithwaite, complex, elt, redistricting, trel, variational,
# Nearest to consists: consisting, pago, radiodiffusion, assembly, branson, congruent, linden, frictional,
# Nearest to frac: velocity, sqrt, tangent, quantity, gemara, marginal, dagome, equation,
# Nearest to lived: him, paris, infancy, warrens, lipsius, spread, registrar, worked,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9428 0.0228 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9861 0.0219 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9942 0.0220 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0133 0.0218 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0418 0.0218 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0397 0.0193 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9964 0.0219 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9695 0.0220 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9848 0.0219 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9480 0.0217 sec/batch
# Nearest to these: compiles, tailplane, forage, gneisses, have, firewalls, enact, miraculous,
# Nearest to see: pragmatically, plaudits, jericho, ong, lingerie, maimonides, transcended, seifert,
# Nearest to for: the, shema, euphemistically, fungal, dina, magyars, awarded, its,
# Nearest to an: a, nonterminal, stay, pompeii, domestication, ucsd, propylaea, diffusing,
# Nearest to one: two, eight, nine, zero, five, four, seven, six,
# Nearest to by: in, march, produce, footnotes, squaring, and, affluence, chroniclers,
# Nearest to however: to, composting, zoster, that, keweenaw, hysteria, thereby, spreading,
# Nearest to so: unsuspecting, quell, superscript, estranged, able, memex, functionary, jena,
# Nearest to hit: mel, centimeter, phillies, pitch, teammate, contemplative, kirchner, dogwood,
# Nearest to shown: resonances, placebo, longed, testosterone, phosphate, kidnapped, gives, outfit,
# Nearest to writers: novelists, poets, dramatists, burials, compulsories, fellows, upanishad, deaths,
# Nearest to report: whims, reporting, compliance, weider, zeitung, taverns, zalman, hadron,
# Nearest to mathematics: empirical, ptolemaic, redistricting, complex, trel, elt, braithwaite, variational,
# Nearest to consists: consisting, pago, linden, branson, radiodiffusion, congruent, frictional, assembly,
# Nearest to frac: velocity, sqrt, tangent, gemara, quantity, marginal, waitakere, antiderivatives,
# Nearest to lived: him, paris, warrens, infancy, lipsius, mother, registrar, spread,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9598 0.0228 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8787 0.0219 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9393 0.0219 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9790 0.0217 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0037 0.0217 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9620 0.0217 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8708 0.0217 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9372 0.0217 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8978 0.0217 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9188 0.0216 sec/batch
# Nearest to these: compiles, have, tailplane, for, gneisses, tasks, forage, firewalls,
# Nearest to see: pragmatically, plaudits, three, jericho, ong, lingerie, in, called,
# Nearest to for: the, shema, euphemistically, to, fungal, its, of, copper,
# Nearest to an: stay, a, pompeii, czes, diffusing, infirm, ucsd, domestication,
# Nearest to one: two, eight, nine, zero, five, four, seven, six,
# Nearest to by: in, footnotes, march, produce, squaring, advancements, and, heath,
# Nearest to however: to, zoster, composting, that, keweenaw, adaptive, thereby, hysteria,
# Nearest to so: unsuspecting, quell, memex, estranged, superscript, able, land, herrmann,
# Nearest to hit: pitch, centimeter, mel, teammate, contemplative, dogwood, phillies, kirchner,
# Nearest to shown: resonances, placebo, longed, phosphate, following, gives, armies, testosterone,
# Nearest to writers: novelists, poets, upanishad, fellows, compulsories, burials, dramatists, deaths,
# Nearest to report: whims, reporting, compliance, zalman, zeitung, ngos, jazeera, weider,
# Nearest to mathematics: empirical, ptolemaic, complex, trel, redistricting, braithwaite, elt, andrzej,
# Nearest to consists: consisting, linden, pago, varitek, congruent, branson, radiodiffusion, assembly,
# Nearest to frac: velocity, sqrt, tangent, quantity, equation, gemara, marginal, antiderivatives,
# Nearest to lived: him, infancy, lipsius, paris, registrar, warrens, worked, mother,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9728 0.0227 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9853 0.0219 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9271 0.0217 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9706 0.0217 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9901 0.0217 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9472 0.0218 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9735 0.0217 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9511 0.0218 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9364 0.0220 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9493 0.0219 sec/batch
# Nearest to these: compiles, have, for, firewalls, tailplane, shows, tasks, teleological,
# Nearest to see: pragmatically, plaudits, ong, bayes, transcended, lingerie, jericho, maimonides,
# Nearest to for: the, awarded, its, shema, these, euphemistically, of, fungal,
# Nearest to an: a, stay, czes, homophobia, the, diffusing, gpa, transnational,
# Nearest to one: two, eight, nine, zero, seven, four, five, six,
# Nearest to by: in, squaring, produce, march, footnotes, and, laureates, advancements,
# Nearest to however: zoster, to, adaptive, composting, that, keweenaw, wahid, naturals,
# Nearest to so: unsuspecting, memex, estranged, quell, land, able, functionary, superscript,
# Nearest to hit: mel, centimeter, dogwood, pitch, teammate, kirchner, phillies, gere,
# Nearest to shown: placebo, resonances, phosphate, longed, outfit, testosterone, branden, stagnating,
# Nearest to writers: novelists, dramatists, deaths, poets, fellows, compulsories, alumni, upanishad,
# Nearest to report: whims, compliance, reporting, zalman, ngos, zeitung, reissue, weider,
# Nearest to mathematics: empirical, trel, complex, ptolemaic, elt, redistricting, cyber, braithwaite,
# Nearest to consists: consisting, linden, branson, varitek, congruent, frictional, pago, nuances,
# Nearest to frac: velocity, sqrt, quantity, tangent, equation, gemara, marginal, antiderivatives,
# Nearest to lived: him, mother, infancy, lipsius, warrens, worked, paris, registrar,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9636 0.0229 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9445 0.0219 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9432 0.0218 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9592 0.0218 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9821 0.0218 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9744 0.0218 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9615 0.0218 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9394 0.0218 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9404 0.0218 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9791 0.0219 sec/batch
# Nearest to these: have, compiles, tailplane, firewalls, for, dimethyltryptamine, gneisses, islamism,
# Nearest to see: pragmatically, plaudits, list, three, ong, jericho, the, bayes,
# Nearest to for: the, awarded, its, of, to, magyars, shema, these,
# Nearest to an: a, stay, transnational, diffusing, the, czes, domestication, gpa,
# Nearest to one: two, eight, nine, zero, four, five, seven, three,
# Nearest to by: in, march, and, advancements, footnotes, produce, heath, scone,
# Nearest to however: to, that, zoster, composting, fluency, wahid, coprime, thereby,
# Nearest to so: unsuspecting, memex, able, superscript, estranged, quell, functionary, withdrew,
# Nearest to hit: teammate, centimeter, phillies, mel, dogwood, kirchner, contemplative, pitch,
# Nearest to shown: placebo, resonances, phosphate, longed, stagnating, testosterone, truthful, outfit,
# Nearest to writers: novelists, dramatists, poets, fellows, compulsories, burials, deaths, upanishad,
# Nearest to report: whims, compliance, reporting, zalman, zeitung, ngos, godless, jazeera,
# Nearest to mathematics: empirical, ptolemaic, trel, elt, andrzej, complex, student, dahmer,
# ...
# Nearest to lived: him, nucleosynthesis, suffect, mother, registrar, infancy, worked, uncommon,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8464 0.0229 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7119 0.0217 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8201 0.0218 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7509 0.0217 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7532 0.0216 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8126 0.0217 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8391 0.0218 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7681 0.0218 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8259 0.0217 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9033 0.0217 sec/batch
# Nearest to these: have, other, for, are, and, compiles, in, different,
# Nearest to see: of, in, the, list, external, links, three, article,
# Nearest to for: the, is, of, to, and, a, in, these,
# Nearest to an: a, of, the, in, and, as, which, czes,
# Nearest to one: two, nine, eight, four, seven, zero, five, six,
# Nearest to by: in, and, a, of, along, two, with, as,
# Nearest to however: to, that, not, their, from, zoster, because, thereby,
# Nearest to so: come, unsuspecting, memex, will, where, stronger, kearny, superscript,
# Nearest to hit: superstars, centimeter, pitch, hits, mel, whoso, unicef, gere,
# Nearest to shown: placebo, resonances, refreshed, phosphate, following, outfit, billings, certain,
# Nearest to writers: novelists, poets, dramatists, hugo, fellows, deaths, unbelief, alumni,
# Nearest to report: reporting, ngos, restraint, zalman, godless, antonia, reissue, reports,
# Nearest to mathematics: sheaf, cyber, aphex, trel, krakow, eea, aaaa, elt,
# Nearest to consists: consisting, congruent, linden, varitek, respects, subdivide, frictional, wired,
# Nearest to frac: velocity, equation, sqrt, waitakere, marginal, quantity, loudspeakers, right,
# Nearest to lived: nucleosynthesis, worked, infancy, suffect, him, registrar, easing, uncommon,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8107 0.0228 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.7846 0.0218 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8417 0.0217 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8201 0.0218 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.7977 0.0217 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8358 0.0218 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8140 0.0217 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7950 0.0216 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8442 0.0217 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8068 0.0218 sec/batch
# Nearest to these: have, other, for, and, are, in, compiles, islamism,
# Nearest to see: of, the, in, list, links, external, three, and,
# Nearest to for: the, of, to, is, and, in, ever, a,
# Nearest to an: a, of, the, which, in, czes, and, is,
# Nearest to one: two, eight, nine, four, seven, zero, five, six,
# Nearest to by: in, and, of, a, along, two, the, produce,
# Nearest to however: to, that, their, not, from, because, thereby, this,
# Nearest to so: come, unsuspecting, memex, herrmann, kearny, jena, whether, where,
# Nearest to hit: superstars, centimeter, mel, hits, pitch, unicef, kirchner, whoso,
# Nearest to shown: placebo, resonances, outfit, phosphate, billings, refreshed, mediate, stagnating,
# Nearest to writers: novelists, poets, dramatists, hugo, fellows, alumni, burials, deaths,
# Nearest to report: reporting, ngos, zalman, restraint, reports, reissue, whims, blame,
# Nearest to mathematics: sheaf, trel, eea, krakow, aphex, ptolemaic, elt, cyber,
# Nearest to consists: consisting, congruent, subdivide, respects, linden, varitek, frictional, wired,
# Nearest to frac: velocity, equation, waitakere, loudspeakers, sqrt, marginal, quantity, guralnick,
# Nearest to lived: worked, nucleosynthesis, suffect, mother, warrens, him, infancy, polonium,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8675 0.0228 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8261 0.0217 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8018 0.0218 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8139 0.0217 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8491 0.0218 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8171 0.0219 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9144 0.0218 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8681 0.0218 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8883 0.0217 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7818 0.0218 sec/batch
# Nearest to these: have, other, are, and, for, well, islamism, many,
# Nearest to see: list, of, the, in, links, external, three, also,
# Nearest to for: the, of, and, is, to, as, a, in,
# Nearest to an: a, of, the, in, and, as, which, for,
# Nearest to one: two, four, nine, eight, seven, zero, five, six,
# Nearest to by: in, and, a, of, two, along, one, with,
# Nearest to however: to, that, not, their, because, thereby, zoster, from,
# Nearest to so: come, unsuspecting, memex, does, will, whether, without, superscript,
# Nearest to hit: centimeter, superstars, mel, kirchner, hits, yorker, unicef, deliciosa,
# Nearest to shown: placebo, resonances, outfit, following, billings, stagnating, mediate, refreshed,
# Nearest to writers: novelists, poets, dramatists, hugo, alumni, fellows, deaths, sportspeople,
# Nearest to report: reporting, ngos, restraint, reports, saic, blame, jazeera, godless,
# Nearest to mathematics: trel, krakow, sheaf, ptolemaic, neville, aphex, bardeen, student,
# Nearest to consists: consisting, congruent, subdivide, respects, linden, wired, frictional, geography,
# Nearest to frac: velocity, equation, sqrt, marginal, loudspeakers, waitakere, quantity, guralnick,
# Nearest to lived: worked, nucleosynthesis, infancy, pittsburg, warrens, suffect, mother, malenkov,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7586 0.0228 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8461 0.0218 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7663 0.0218 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8422 0.0217 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8191 0.0218 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8096 0.0218 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8793 0.0107 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8065 0.0217 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7802 0.0218 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8066 0.0218 sec/batch
# Nearest to these: have, other, are, and, for, well, different, the,
# Nearest to see: of, list, in, links, also, the, external, three,
# Nearest to for: the, of, and, is, to, a, in, as,
# Nearest to an: a, of, the, in, and, which, as, called,
# Nearest to one: two, eight, nine, four, seven, five, zero, six,
# Nearest to by: in, and, of, a, the, with, along, two,
# Nearest to however: to, that, not, their, because, from, zoster, botulinum,
# Nearest to so: come, unsuspecting, memex, does, without, herrmann, to, kearny,
# Nearest to hit: centimeter, superstars, kirchner, mel, hits, tilsit, supercomputer, dogwood,
# Nearest to shown: placebo, resonances, refreshed, deepened, billings, phosphate, howard, stagnating,
# Nearest to writers: novelists, poets, dramatists, hugo, fellows, alumni, deaths, burials,
# Nearest to report: reporting, ngos, restraint, antonia, godless, reissue, saic, jadavpur,
# Nearest to mathematics: sheaf, ptolemaic, krakow, trel, central, aphex, aaaa, eea,
# Nearest to consists: consisting, congruent, subdivide, respects, wired, linden, chambre, load,
# Nearest to frac: velocity, sqrt, equation, marginal, loudspeakers, waitakere, sih, khanate,
# Nearest to lived: worked, nucleosynthesis, him, mother, infancy, warrens, suffect, pittsburg,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7876 0.0229 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7697 0.0218 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7840 0.0218 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7539 0.0217 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8055 0.0218 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8208 0.0217 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8226 0.0217 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7122 0.0217 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7853 0.0218 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7800 0.0218 sec/batch
# Nearest to these: have, other, and, are, for, different, in, the,
# Nearest to see: of, the, in, list, links, external, also, three,
# Nearest to for: the, is, of, in, to, and, a, on,
# Nearest to an: a, the, of, in, is, as, for, and,
# Nearest to one: two, eight, nine, four, seven, zero, five, six,
# Nearest to by: in, and, a, of, produce, as, along, with,
# Nearest to however: to, that, their, not, zoster, because, from, this,
# Nearest to so: unsuspecting, come, does, memex, without, a, kearny, pool,
# Nearest to hit: hits, superstars, centimeter, pitch, mel, kirchner, gere, dogwood,
# Nearest to shown: placebo, following, refreshed, resonances, billings, mediate, deepened, are,
# Nearest to writers: novelists, poets, dramatists, hugo, fellows, alumni, deaths, satirists,
# Nearest to report: reporting, restraint, ngos, reports, jadavpur, saic, reissue, zine,
# Nearest to mathematics: sheaf, trel, krakow, ptolemaic, aphex, eea, elt, assent,
# Nearest to consists: consisting, respects, subdivide, congruent, varitek, linden, load, geography,
# Nearest to frac: velocity, equation, sqrt, loudspeakers, marginal, waitakere, gemara, sih,
# Nearest to lived: nucleosynthesis, worked, pittsburg, warrens, squaresoft, him, infancy, suffect,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7063 0.0227 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7732 0.0217 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8140 0.0217 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8136 0.0216 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7830 0.0217 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8508 0.0217 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7915 0.0218 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7756 0.0217 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7489 0.0217 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7831 0.0217 sec/batch
# Nearest to these: have, other, are, and, for, the, in, different,
# Nearest to see: of, the, list, in, links, also, external, article,
# Nearest to for: the, of, is, and, in, to, a, as,
# Nearest to an: of, the, a, in, as, which, and, for,
# Nearest to one: two, eight, four, nine, seven, zero, six, five,
# Nearest to by: in, and, of, a, two, as, the, along,
# Nearest to however: to, that, not, their, from, because, zoster, be,
# Nearest to so: come, unsuspecting, does, memex, without, pool, will, kearny,
# Nearest to hit: hits, superstars, centimeter, pitch, mel, unicef, album, kirchner,
# Nearest to shown: placebo, billings, refreshed, resonances, deepened, certain, following, phosphate,
# Nearest to writers: novelists, poets, dramatists, deaths, hugo, fellows, alumni, satirists,
# Nearest to report: reporting, restraint, ngos, reports, antonia, saic, godless, reissue,
# Nearest to mathematics: trel, sheaf, central, aphex, assent, cyber, krakow, elt,
# Nearest to consists: consisting, respects, subdivide, congruent, varitek, linden, geography, load,
# Nearest to frac: velocity, sqrt, equation, loudspeakers, marginal, waitakere, gemara, right,
# Nearest to lived: nucleosynthesis, pittsburg, mother, infancy, squaresoft, worked, warrens, him,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8559 0.0228 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7650 0.0218 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7951 0.0218 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8111 0.0218 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8366 0.0218 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8196 0.0218 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7862 0.0216 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8330 0.0218 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8136 0.0217 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8073 0.0217 sec/batch
# Nearest to these: have, are, other, and, for, the, in, of,
# Nearest to see: of, the, in, list, links, and, also, external,
# Nearest to for: the, of, to, is, a, in, and, one,
# Nearest to an: the, of, a, in, as, for, which, and,
# Nearest to one: two, eight, four, seven, zero, nine, five, six,
# Nearest to by: in, and, of, a, two, the, one, as,
# Nearest to however: to, that, not, their, from, be, this, because,
# Nearest to so: come, does, unsuspecting, where, without, will, memex, accepted,
# Nearest to hit: superstars, hits, centimeter, tilsit, unicef, mel, kirchner, nami,
# Nearest to shown: placebo, billings, refreshed, resonances, howard, following, comet, outfit,
# Nearest to writers: novelists, poets, dramatists, hugo, deaths, satirists, burials, fellows,
# Nearest to report: reporting, reports, ngos, restraint, jadavpur, antonia, zeitung, saic,
# Nearest to mathematics: ptolemaic, sheaf, assent, central, trel, elt, aphex, krakow,
# Nearest to consists: consisting, respects, subdivide, congruent, geography, load, eight, linden,
# Nearest to frac: loudspeakers, sqrt, velocity, equation, marginal, gemara, waitakere, sih,
# Nearest to lived: worked, nucleosynthesis, warrens, pittsburg, infancy, polonium, malenkov, registrar,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8138 0.0228 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7822 0.0218 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9001 0.0218 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9054 0.0218 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8364 0.0217 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8184 0.0219 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7243 0.0217 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7775 0.0218 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6929 0.0218 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8403 0.0218 sec/batch
# Nearest to these: have, other, are, for, and, different, well, many,
# Nearest to see: of, list, the, in, links, also, external, and,
# Nearest to for: the, a, of, in, and, as, is, to,
# Nearest to an: a, the, of, in, and, as, for, which,
# Nearest to one: two, nine, eight, four, seven, zero, six, five,
# Nearest to by: in, and, a, of, two, the, as, along,
# Nearest to however: to, that, not, be, because, their, from, zoster,
# Nearest to so: come, does, unsuspecting, without, where, memex, will, herrmann,
# Nearest to hit: hits, superstars, centimeter, kirchner, mel, tilsit, pitch, nami,
# Nearest to shown: placebo, billings, refreshed, howard, resonances, mckellen, certain, stagnating,
# Nearest to writers: novelists, poets, dramatists, deaths, hugo, alumni, naturalized, fellows,
# Nearest to report: reporting, reports, ngos, godless, saic, jadavpur, antonia, restraint,
# Nearest to mathematics: sheaf, ptolemaic, trel, central, assent, aphex, elt, aaaa,
# Nearest to consists: consisting, respects, congruent, subdivide, varitek, load, frictional, geography,
# Nearest to frac: sqrt, loudspeakers, velocity, marginal, equation, gemara, waitakere, guralnick,
# Nearest to lived: nucleosynthesis, worked, malenkov, pittsburg, warrens, infancy, polonium, easing,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8198 0.0228 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8067 0.0218 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
